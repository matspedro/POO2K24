// %% [markdown]
// # Atividade 03

// %% [markdown]
// ## Crie uma classe em java capaz de imprimir o seu nome no console.

// %%
//public class Atv03{
//    public static void main(String [] args){
        System.out.print("Matheus Pedro Carvalho");      
//    }
//}
// Out:
// Matheus Pedro Carvalho
// null

// %% [markdown]
// ## Crie uma classe que efetue a leitura de um valor qualquer e exiba o seu respectivo valor na tabela ASCII.

// %%
//import java.io.IOException;

//public class Atv03{
//    public static void main(String [] args) throws IOException{
        System.out.print("Digite um valor:");
        int valor = System.in.read();

        System.out.print("ASCII =" + valor);

//    }
//}
// Out:
// Digite um valor:
//  2
// ASCII =50
// null
